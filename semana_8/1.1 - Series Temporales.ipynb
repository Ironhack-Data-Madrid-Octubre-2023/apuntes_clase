# %% [markdown]
# # 1.1 - Series Temporales
#
# ![time_series](images/time_series.jpg)

# %%
import warnings
warnings.simplefilter('ignore')

import pandas as pd
import numpy as np

import pylab as plt

# %%
df=pd.read_csv('../data/occupancy.csv')

df.head()
# Out:
#              date  Temperature  Humidity       Light         CO2  \
# 0  2/2/2015 14:00      23.7000    26.272  585.200000  749.200000
# 1  2/2/2015 15:00      23.7180    26.290  578.400000  760.400000
# 2  2/2/2015 16:00      23.7300    26.230  572.666667  769.666667
# 3  2/2/2015 17:00      23.7225    26.125  493.750000  774.750000
# 4  2/2/2015 18:00      23.7540    26.200  488.600000  779.000000
#
#    HumidityRatio  Occupancy
# 0       0.004764          1
# 1       0.004773          1
# 2       0.004765          1
# 3       0.004744          1
# 4       0.004767          1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2664 entries, 0 to 2663
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   date           2664 non-null   object
#  1   Temperature    2664 non-null   float64
#  2   Humidity       2664 non-null   float64
#  3   Light          2664 non-null   float64
#  4   CO2            2664 non-null   float64
#  5   HumidityRatio  2664 non-null   float64
#  6   Occupancy      2664 non-null   int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 145.8+ KB

# %%
df.date = pd.to_datetime(df.date)

df.head()
# Out:
#                  date  Temperature  Humidity       Light         CO2  \
# 0 2015-02-02 14:00:00      23.7000    26.272  585.200000  749.200000
# 1 2015-02-02 15:00:00      23.7180    26.290  578.400000  760.400000
# 2 2015-02-02 16:00:00      23.7300    26.230  572.666667  769.666667
# 3 2015-02-02 17:00:00      23.7225    26.125  493.750000  774.750000
# 4 2015-02-02 18:00:00      23.7540    26.200  488.600000  779.000000
#
#    HumidityRatio  Occupancy
# 0       0.004764          1
# 1       0.004773          1
# 2       0.004765          1
# 3       0.004744          1
# 4       0.004767          1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2664 entries, 0 to 2663
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   date           2664 non-null   datetime64[ns]
#  1   Temperature    2664 non-null   float64
#  2   Humidity       2664 non-null   float64
#  3   Light          2664 non-null   float64
#  4   CO2            2664 non-null   float64
#  5   HumidityRatio  2664 non-null   float64
#  6   Occupancy      2664 non-null   int64
# dtypes: datetime64[ns](1), float64(5), int64(1)
# memory usage: 145.8 KB

# %%
# pasar la fecha al indice

df = df.set_index('date')

df.head()
# Out:
#                      Temperature  Humidity       Light         CO2  \
# date
# 2015-02-02 14:00:00      23.7000    26.272  585.200000  749.200000
# 2015-02-02 15:00:00      23.7180    26.290  578.400000  760.400000
# 2015-02-02 16:00:00      23.7300    26.230  572.666667  769.666667
# 2015-02-02 17:00:00      23.7225    26.125  493.750000  774.750000
# 2015-02-02 18:00:00      23.7540    26.200  488.600000  779.000000
#
#                      HumidityRatio  Occupancy
# date
# 2015-02-02 14:00:00       0.004764          1
# 2015-02-02 15:00:00       0.004773          1
# 2015-02-02 16:00:00       0.004765          1
# 2015-02-02 17:00:00       0.004744          1
# 2015-02-02 18:00:00       0.004767          1

# %%
df.CO2.plot();

# %%
df.Light.plot();

# %%
df.Temperature.plot();

# %%
dias = df.CO2.loc['2015-4-1': '2015-4-30']

dias.plot();

# %%
#dias = df.CO2.loc['2015-01-01':'2015-01-30':2]

#dias.plot();

# %% [markdown]
# ### Autoregresión - AR
#
# El modelo usa la relación de dependencia del momento actual con $n$ momentos anteriores. Es, en realidad, una regresión lineal.
#
# $$y_t = \beta_0+\beta_1y_{t-1}+\beta_2y_{t-2}+\ldots+\beta_ny_{t-n}+\epsilon_t$$
#
# Si solamente nos fijamos en el momento anterior, $t-1$, entonces:
#
# $$y_t = \beta_0+\beta_1y_{t-1}+\epsilon_t$$
#
# Es la llamada Cadena de Markov

# %%
from pandas.plotting import lag_plot

# %%
lag_plot(df.CO2)
# Out:
# <AxesSubplot: xlabel='y(t)', ylabel='y(t + 1)'>

# %%
# datos random

lag_plot(pd.Series(np.random.random(1000)));

# %%
# AR

from statsmodels.tsa.ar_model import AutoReg as AR

# %%
train, test = df.CO2[:-10], df.CO2[-10:]

train.shape, test.shape
# Out:
# ((2654,), (10,))

# %%
modelo = AR(train, lags=1).fit()

# lags=1 es la cadena de Markov, lags son los pasos atras que mira
# Out:
# /opt/homebrew/Caskroom/miniconda/base/envs/clase/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency H will be used.
#   self._init_dates(dates, freq)

# %%
len(train), len(df.CO2)-1
# Out:
# (2654, 2663)

# %%
# por indice para predecir

pred = modelo.predict(len(train), len(df.CO2)-1)

len(pred)
# Out:
# 10

# %%
pred
# Out:
# 2015-05-24 04:00:00    1152.762619
# 2015-05-24 05:00:00    1153.025305
# 2015-05-24 06:00:00    1153.288058
# 2015-05-24 07:00:00    1153.550877
# 2015-05-24 08:00:00    1153.813763
# 2015-05-24 09:00:00    1154.076715
# 2015-05-24 10:00:00    1154.339734
# 2015-05-24 11:00:00    1154.602820
# 2015-05-24 12:00:00    1154.865972
# 2015-05-24 13:00:00    1155.129191
# Freq: H, dtype: float64

# %%
test
# Out:
# date
# 2015-05-24 04:00:00    1153.250000
# 2015-05-24 05:00:00    1152.400000
# 2015-05-24 06:00:00    1146.166667
# 2015-05-24 07:00:00    1145.400000
# 2015-05-24 08:00:00    1140.800000
# 2015-05-24 09:00:00    1150.250000
# 2015-05-24 10:00:00    1129.200000
# 2015-05-24 11:00:00    1125.800000
# 2015-05-24 12:00:00    1123.000000
# 2015-05-24 13:00:00    1124.000000
# Name: CO2, dtype: float64

# %%
# error medio absoluto MAE


error = (pred - test).abs().sum()/len(pred)  

error
# Out:
# 15.016314895077766

# %%
res=pd.DataFrame({'real': test, 'pred': pred, 'error': pred - test})

res
# Out:
#                             real         pred      error
# 2015-05-24 04:00:00  1153.250000  1152.762619  -0.487381
# 2015-05-24 05:00:00  1152.400000  1153.025305   0.625305
# 2015-05-24 06:00:00  1146.166667  1153.288058   7.121391
# 2015-05-24 07:00:00  1145.400000  1153.550877   8.150877
# 2015-05-24 08:00:00  1140.800000  1153.813763  13.013763
# 2015-05-24 09:00:00  1150.250000  1154.076715   3.826715
# 2015-05-24 10:00:00  1129.200000  1154.339734  25.139734
# 2015-05-24 11:00:00  1125.800000  1154.602820  28.802820
# 2015-05-24 12:00:00  1123.000000  1154.865972  31.865972
# 2015-05-24 13:00:00  1124.000000  1155.129191  31.129191

# %%
import warnings
warnings.simplefilter('ignore')

for i in range(10, 20, 1):
    
    modelo=AR(train, lags=i).fit()                     # entrenar la AR
    
    pred=modelo.predict(len(train), len(df.CO2)-1)     # la prediccion en el intervalo
    
    error=(pred-test).abs().sum()/len(pred)            # error medio absoluto
    
    print ('Error mae: ', error.round(5), '  Maxlag : ', i)
# Out:
# Error mae:  8.50887   Maxlag :  10
# Error mae:  7.62306   Maxlag :  11
# Error mae:  7.16723   Maxlag :  12
# Error mae:  6.40127   Maxlag :  13
# Error mae:  5.26263   Maxlag :  14
# Error mae:  4.99467   Maxlag :  15
# Error mae:  4.97313   Maxlag :  16
# Error mae:  5.64878   Maxlag :  17
# Error mae:  6.50483   Maxlag :  18
# Error mae:  7.29856   Maxlag :  19

# %% [markdown]
# ### Media Móvil (Moving Average MA)
#
# Una manera matemática de expresar la MA puede ser:
#
# $$y_t = \beta_0+\epsilon_t+\epsilon_{t-1}\phi_{t-1}+\epsilon_{t-2}\phi_{t-2}+\ldots+\epsilon_{t-n}\phi_{t-n}$$
#
#
# Se usa la relación entre las observaciones y el error residual de la media móvil.
#
# Otra es la evidente, la media móvil, se muestra en el gráfico.

# %%
plt.figure(figsize=(10, 5))

plt.plot(dias.values)

plt.plot([50, 80],[1000, 1000], color='black')
plt.plot([50, 50],[1000, 1100], color='black')
plt.plot([50, 80],[1100, 1100], color='black')
plt.plot([80, 80],[1000, 1100], color='black')

plt.quiver(80, 1050, 1, 0, scale=20, color='r');

# %%
import statsmodels.api as sm

res=sm.tsa.seasonal_decompose(dias)

resplot=res.plot()

# %% [markdown]
# ### ARMA (AutoRegressive Moving Average)
#
# Unión de ambos conceptos.
#
# $$y_t = \beta_0 + \epsilon_t + \sum_{i=1}^{n}\beta_iy_{t-i} + \sum_{i=1}^{m}\phi_i\epsilon_{t-i}$$

# %%
# ARIMA  order==> (p, d, q)  d=>Integrated , d=0 es ARMA

# ARMA  order==> p=>AR (n, maxlag), q=>MA (m, ancho de la ventana)

from statsmodels.tsa.arima.model import ARIMA

# %%
# %%time

modelo=ARIMA(train, order=(16, 0, 3)).fit()  # d=0 implica ARMA
# Out:
# CPU times: user 7.96 s, sys: 1.02 s, total: 8.98 s
# Wall time: 6.99 s

# %%
pred=modelo.predict(len(train), len(df.CO2)-1) 

error=(pred-test).abs().sum()/len(pred) 

print ('Error mae: ', error)

res=pd.DataFrame({'real':test, 'pred':pred, 'error':pred-test})

res
# Out:
# Error mae:  15.708393323041946
#                             real         pred      error
# 2015-05-24 04:00:00  1153.250000  1153.365846   0.115846
# 2015-05-24 05:00:00  1152.400000  1152.938572   0.538572
# 2015-05-24 06:00:00  1146.166667  1153.061681   6.895014
# 2015-05-24 07:00:00  1145.400000  1154.338221   8.938221
# 2015-05-24 08:00:00  1140.800000  1155.057075  14.257075
# 2015-05-24 09:00:00  1150.250000  1155.478864   5.228864
# 2015-05-24 10:00:00  1129.200000  1155.682302  26.482302
# 2015-05-24 11:00:00  1125.800000  1156.121413  30.321413
# 2015-05-24 12:00:00  1123.000000  1155.846848  32.846848
# 2015-05-24 13:00:00  1124.000000  1155.459779  31.459779

# %% [markdown]
# ### ARIMA (AutoRegressive Integrated Moving Average)
#
# Lo de Integrated trata de hacer la serie temporal estacionaria, similar al concepto de PID.

# %%
# %%time

modelo=ARIMA(train, order=(4, 1, 2)).fit()

                     
pred=modelo.predict(len(train), len(df.CO2)-1) 

error=(pred-test).abs().sum()/len(pred) 

print ('Error mae: ', error)

res=pd.DataFrame({'real':test, 'pred':pred, 'error':pred-test})
res
# Out:
# Error mae:  17.33208608482107
# CPU times: user 1.59 s, sys: 547 ms, total: 2.14 s
# Wall time: 413 ms
#                             real         pred      error
# 2015-05-24 04:00:00  1153.250000  1153.285761   0.035761
# 2015-05-24 05:00:00  1152.400000  1153.607865   1.207865
# 2015-05-24 06:00:00  1146.166667  1154.459560   8.292893
# 2015-05-24 07:00:00  1145.400000  1155.189745   9.789745
# 2015-05-24 08:00:00  1140.800000  1156.021367  15.221367
# 2015-05-24 09:00:00  1150.250000  1156.710475   6.460475
# 2015-05-24 10:00:00  1129.200000  1157.501011  28.301011
# 2015-05-24 11:00:00  1125.800000  1158.197106  32.397106
# 2015-05-24 12:00:00  1123.000000  1158.960983  35.960983
# 2015-05-24 13:00:00  1124.000000  1159.653655  35.653655

# %% [markdown]
# ### ADF-test (testeo de la estacionaridad)
#
# https://www.statsmodels.org/stable/generated/statsmodels.tsa.stattools.adfuller.html

# %% [markdown]
# ### SARIMA (Seasonal AutoRegressive Integrated Moving Average)
# Arima por estaciones.
#
# ### SARIMAX (Seasonal AutoRegressive Integrated Moving Average Exogenous)
# SARIMA con regresores exógenos.

# %%
from statsmodels.tsa.statespace.sarimax import SARIMAX

# %%
#help(SARIMAX)

# %%
# %%time

modelo=SARIMAX(endog=train, 
               exog=None,
               #order=(4, 1, 5),  # modelo arima
               seasonal_order=(4, 1, 5, 2) # modelo sarima, estacionalidad es el ultimo
              ).fit(disp=False)
                     
pred=modelo.predict(len(train), len(df.CO2)-1)  

error=(pred-test).abs().sum()/len(pred) 
print ('Error mae: ', error)


res=pd.DataFrame({'real':test, 'pred':pred, 'error':pred-test})
res
# Out:
# Error mae:  23.71677690108377
# CPU times: user 4.09 s, sys: 689 ms, total: 4.78 s
# Wall time: 2.92 s
#                             real         pred      error
# 2015-05-24 04:00:00  1153.250000  1155.944783   2.694783
# 2015-05-24 05:00:00  1152.400000  1155.687332   3.287332
# 2015-05-24 06:00:00  1146.166667  1159.952051  13.785384
# 2015-05-24 07:00:00  1145.400000  1159.650394  14.250394
# 2015-05-24 08:00:00  1140.800000  1163.182482  22.382482
# 2015-05-24 09:00:00  1150.250000  1162.561503  12.311503
# 2015-05-24 10:00:00  1129.200000  1165.790653  36.590653
# 2015-05-24 11:00:00  1125.800000  1165.587561  39.787561
# 2015-05-24 12:00:00  1123.000000  1169.748092  46.748092
# 2015-05-24 13:00:00  1124.000000  1169.329586  45.329586

# %% [markdown]
# ## FB-Prophet
#
# https://facebook.github.io/prophet/docs/quick_start.html

# %%
# %pip install prophet

# %%
# %pip install pystan==2.19.1.1

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt


from prophet import Prophet


from sklearn.metrics import mean_squared_error, mean_absolute_error

plt.style.use('fivethirtyeight')

# %%
# datos, consumo de energia

pjme=pd.read_csv('../data/PJME_hourly.csv', index_col=[0], parse_dates=[0])
pjme.tail()
# Out:
#                      PJME_MW
# Datetime
# 2018-01-01 20:00:00  44284.0
# 2018-01-01 21:00:00  43751.0
# 2018-01-01 22:00:00  42402.0
# 2018-01-01 23:00:00  40164.0
# 2018-01-02 00:00:00  38608.0

# %%
_=pjme.plot(style='.', figsize=(15, 5), color='r', title='PJME')

# %%
# se definen las caracteristicas temporales

def features(df, label):
    
    df=df.copy()
    
    df['date']=df.index
    df['hour']=df.date.dt.hour
    df['day_of_week']=df.date.dt.dayofweek
    df['quarter']=df.date.dt.quarter
    df['month']=df.date.dt.month
    df['year']=df.date.dt.year
    df['day_of_year']=df.date.dt.dayofyear
    df['day_of_month']=df.date.dt.day
    df['week_of_year']=df.date.dt.weekofyear
    
    X=df[['hour', 'day_of_week', 'quarter', 'month', 'year',
          'day_of_year', 'day_of_month', 'week_of_year']]
    y=df[label]
    
    return X,y

# %%
X, y = features(pjme, 'PJME_MW')

data=pd.concat([X, y], axis=1)

data.head()
# Out:
#                      hour  day_of_week  quarter  month  year  day_of_year  \
# Datetime
# 2002-12-31 01:00:00     1            1        4     12  2002          365
# 2002-12-31 02:00:00     2            1        4     12  2002          365
# 2002-12-31 03:00:00     3            1        4     12  2002          365
# 2002-12-31 04:00:00     4            1        4     12  2002          365
# 2002-12-31 05:00:00     5            1        4     12  2002          365
#
#                      day_of_month  week_of_year  PJME_MW
# Datetime
# 2002-12-31 01:00:00            31             1  26498.0
# 2002-12-31 02:00:00            31             1  25147.0
# 2002-12-31 03:00:00            31             1  24574.0
# 2002-12-31 04:00:00            31             1  24393.0
# 2002-12-31 05:00:00            31             1  24860.0

# %%
sns.pairplot(data.dropna(), 
             hue='hour', 
             x_vars=['hour', 'day_of_week', 'year', 'week_of_year'],
             y_vars='PJME_MW', 
             height=5, plot_kws={'alpha':0.1, 'linewidth':0})

plt.suptitle('MW por hora, dia, dia de la semana, y semana del año')
plt.show();

# %%
split_date='01-Jan-2015'

train=pjme.loc[pjme.index<=split_date].copy()

test=pjme.loc[pjme.index>split_date].copy()

_=test.rename(columns={'PJME_MW': 'Test'})\
      .join(train.rename(columns={'PJME_MW': 'Train'}), how='outer')\
      .plot(figsize=(15,5), title='PJME', style='.')

# %%
# IMPORTANTE, fbprophet necesita estos nombres de columnas

train=train.reset_index().rename(columns={'Datetime':'ds', 'PJME_MW':'y'})

test=test.reset_index().rename(columns={'Datetime':'ds', 'PJME_MW':'y'})

train.head()
# Out:
#                    ds        y
# 0 2002-12-31 01:00:00  26498.0
# 1 2002-12-31 02:00:00  25147.0
# 2 2002-12-31 03:00:00  24574.0
# 3 2002-12-31 04:00:00  24393.0
# 4 2002-12-31 05:00:00  24860.0

# %%
test.head()
# Out:
#                    ds        y
# 0 2015-12-31 01:00:00  24305.0
# 1 2015-12-31 02:00:00  23156.0
# 2 2015-12-31 03:00:00  22514.0
# 3 2015-12-31 04:00:00  22330.0
# 4 2015-12-31 05:00:00  22773.0

# %%
# %%time

modelo=Prophet().fit(train)

pred=modelo.predict(test)
# Out:
# 09:33:20 - cmdstanpy - INFO - Chain [1] start processing
# 09:33:56 - cmdstanpy - INFO - Chain [1] done processing
# CPU times: user 9.94 s, sys: 2.2 s, total: 12.1 s
# Wall time: 46 s

# %%
f, ax=plt.subplots(1)
f.set_figheight(5)
f.set_figwidth(15)

fig=modelo.plot(pred, ax=ax)

# %%
# comparando

f, ax=plt.subplots(1)
f.set_figheight(5)
f.set_figwidth(15)
ax.scatter(test.ds, test.y, color='r')
fig=modelo.plot(pred, ax)

# %%
# metricas de error

mean_squared_error(test.y, pred.yhat)**0.5
# Out:
# 6617.434811308175

# %%
# Con vacaciones

from pandas.tseries.holiday import USFederalHolidayCalendar as calendar

cal = calendar()

train_h = cal.holidays(train.index.min(), train.index.max())

test_h = cal.holidays(test.index.min(), test.index.max())

# %%
pjme['date'] = pjme.index.date

pjme['is_holiday'] = pjme.date.isin([d.date() for d in cal.holidays()])

df_h = pjme.loc[pjme['is_holiday']].reset_index().rename(columns={'Datetime':'ds'})

df_h['holiday'] = 'USFederalHoliday'

df_h = df_h.drop(['PJME_MW','date','is_holiday'], axis=1)

df_h.head()
# Out:
#                    ds           holiday
# 0 2003-01-01 00:00:00  USFederalHoliday
# 1 2002-12-25 01:00:00  USFederalHoliday
# 2 2002-12-25 02:00:00  USFederalHoliday
# 3 2002-12-25 03:00:00  USFederalHoliday
# 4 2002-12-25 04:00:00  USFederalHoliday

# %%
modelo_h=Prophet(holidays=df_h).fit(train)

fig2=modelo_h.plot_components(pred)
# Out:
# 09:34:07 - cmdstanpy - INFO - Chain [1] start processing
# 09:34:39 - cmdstanpy - INFO - Chain [1] done processing

# %%
pred_h=modelo_h.predict(test)

pred_h.head()
# Out:
#                    ds         trend    yhat_lower    yhat_upper   trend_lower  \
# 0 2015-01-01 01:00:00  31262.809713  22186.963946  31198.200107  31262.809713
# 1 2015-01-01 02:00:00  31262.772950  20793.288666  29497.475475  31262.772950
# 2 2015-01-01 03:00:00  31262.736187  19856.781875  28699.397299  31262.736187
# 3 2015-01-01 04:00:00  31262.699424  19845.356208  28541.422529  31262.699424
# 4 2015-01-01 05:00:00  31262.662661  20300.901205  29147.296617  31262.662661
#
#     trend_upper  USFederalHoliday  USFederalHoliday_lower  \
# 0  31262.809713      -1836.582562            -1836.582562
# 1  31262.772950      -1836.582562            -1836.582562
# 2  31262.736187      -1836.582562            -1836.582562
# 3  31262.699424      -1836.582562            -1836.582562
# 4  31262.662661      -1836.582562            -1836.582562
#
#    USFederalHoliday_upper  additive_terms  ...       weekly  weekly_lower  \
# 0            -1836.582562    -4530.096389  ...  1292.758735   1292.758735
# 1            -1836.582562    -6033.526827  ...  1284.977318   1284.977318
# 2            -1836.582562    -6904.611737  ...  1275.632832   1275.632832
# 3            -1836.582562    -7045.872245  ...  1264.858445   1264.858445
# 4            -1836.582562    -6371.568738  ...  1252.804068   1252.804068
#
#    weekly_upper      yearly  yearly_lower  yearly_upper  multiplicative_terms  \
# 0   1292.758735  444.121697    444.121697    444.121697                   0.0
# 1   1284.977318  445.422622    445.422622    445.422622                   0.0
# 2   1275.632832  446.761273    446.761273    446.761273                   0.0
# 3   1264.858445  448.137678    448.137678    448.137678                   0.0
# 4   1252.804068  449.551865    449.551865    449.551865                   0.0
#
#    multiplicative_terms_lower  multiplicative_terms_upper          yhat
# 0                         0.0                         0.0  26732.713325
# 1                         0.0                         0.0  25229.246123
# 2                         0.0                         0.0  24358.124450
# 3                         0.0                         0.0  24216.827178
# 4                         0.0                         0.0  24891.093922
#
# [5 rows x 28 columns]

# %%
mean_squared_error(test.y, pred_h.yhat, squared=False)
# Out:
# 6625.824739685804

# %% [markdown]
# ### Yahoo Finance

# %%
#%pip install yfinance

# %%
import pandas as pd
import yfinance as yf

import time

# %%
data=yf.download(tickers='AAPL', period='5d', interval='1m')

data['datetime']=data.index

data.to_dict(orient='records')[-1]
# Out:
# [*********************100%***********************]  1 of 1 completed
# {'Open': 189.97000122070312,
#  'High': 189.97000122070312,
#  'Low': 189.97000122070312,
#  'Close': 189.97000122070312,
#  'Adj Close': 189.97000122070312,
#  'Volume': 6457382,
#  'datetime': Timestamp('2023-11-24 13:00:00')}

# %%
data=yf.download(tickers='UBER', period='5d', interval='1m')

data['datetime']=data.index

data.to_dict(orient='records')[-1]
# Out:
# [*********************100%***********************]  1 of 1 completed
# {'Open': 55.31999969482422,
#  'High': 55.31999969482422,
#  'Low': 55.31999969482422,
#  'Close': 55.31999969482422,
#  'Adj Close': 55.31999969482422,
#  'Volume': 0,
#  'datetime': Timestamp('2023-11-24 13:00:00')}

# %%
data=yf.download(tickers='^DJI', period='5d', interval='1m')

data['datetime']=data.index

data.to_dict(orient='records')[-1]
# Out:
# [*********************100%***********************]  1 of 1 completed
# {'Open': 35390.6796875,
#  'High': 35390.73828125,
#  'Low': 35389.890625,
#  'Close': 35390.1484375,
#  'Adj Close': 35390.1484375,
#  'Volume': 17096478,
#  'datetime': Timestamp('2023-11-24 13:00:00')}

# %%
data=yf.download(tickers='^IBEX', period='5d', interval='1m')

data['datetime']=data.index

data.tail()
# Out:
# [*********************100%***********************]  1 of 1 completed
#                             Open         High          Low        Close  \
# Datetime
# 2023-11-27 09:15:00  9950.799805  9958.099609  9950.799805  9957.200195
# 2023-11-27 09:16:00  9957.099609  9960.099609  9954.799805  9960.099609
# 2023-11-27 09:17:00  9959.799805  9959.799805  9956.599609  9957.299805
# 2023-11-27 09:18:00  9957.799805  9960.500000  9957.799805  9960.500000
# 2023-11-27 09:19:00  9960.900391  9960.900391  9960.900391  9960.900391
#
#                        Adj Close  Volume            datetime
# Datetime
# 2023-11-27 09:15:00  9957.200195  168066 2023-11-27 09:15:00
# 2023-11-27 09:16:00  9960.099609  161627 2023-11-27 09:16:00
# 2023-11-27 09:17:00  9957.299805  155613 2023-11-27 09:17:00
# 2023-11-27 09:18:00  9960.500000  392621 2023-11-27 09:18:00
# 2023-11-27 09:19:00  9960.900391       0 2023-11-27 09:19:00

# %%
while 1:
    data=yf.download(tickers='^IBEX', period='5d', interval='1m')

    data['datetime']=data.index

    print(data.tail(1))
    
    time.sleep(0.5)

# %% [markdown]
# ## Ejemplo HyperOpt

# %%
import pandas as pd

from tools.tools import Logger

from sklearn.metrics import mean_squared_error as mse
from sklearn.metrics import mean_absolute_error as mae

from statsmodels.tsa.arima.model import ARIMA

from datetime import date, timedelta

from hyperopt import fmin, hp, tpe, Trials, STATUS_OK

import os

import warnings
warnings.filterwarnings('ignore')

PATH = os.path.dirname(os.path.abspath(__file__))


# create logger
logger = Logger('Log').logger
logger.info('Starting...')


# aprioris
space={'p': hp.quniform('p', 1, 15, 1),  # distribucion uniforme discreta
    
       'd': hp.quniform('d', 1, 15, 1),  
        
       'q': hp.quniform('q', 1, 15, 1),
       }



def arima_model():

    global space, PATH
 
    result = pd.DataFrame()
    stats_train = pd.DataFrame()
    
    N = 8
    
    columns = ['zone', 'date',  
               'visits', 'new_visits', 'recurrents', 'visitors_unique']
        
    today = date.today()     #date(2023, 8, 1)

    data = pd.read_csv(PATH + '/../data/raw/raw_data_daily.csv', usecols=columns)

    data = data[(data['date'] > str(today - timedelta(days=90))) & (data['date'] <= str(today))]
    
    zones = data.zone.unique().tolist()

    logger.info(zones)
    logger.info(len(zones))
    
    for zone in zones:
        
        df = data[data.zone==zone].reset_index(drop=True)
            
        df = df.sort_values(by='date').reset_index(drop=True)
        
        stats_train_tmp_df = pd.DataFrame()
        tmp_df = pd.DataFrame()
        
        for c in columns[2:]:
            
            media = df[c][-N:].mean()
            media2 = df[c][:-N].mean()

            df[c] = df[c].apply(lambda x: x if x>0 else df[c].mean())
            
            logger.info(f'{zone.upper()}  .....  {c.upper()}  ..... Avg Train:  {round(media, 2)}  ...... Avg Test:  {round(media2, 2)}')
            
            train, test = df[c][:-N], df[c][-N:]

            def objetivo(space):
    
                modelo = ARIMA(train, order=(space['p'], space['d'], space['q']))

                modelo.initialize_approximate_diffuse()

                trained = modelo.fit()

                pred = trained.predict(train.shape[0], df.shape[0]-1)

                pred = pred.fillna(test.mean())

                loss=mse(test, pred, squared=False)

                return {'loss': loss, 'status': STATUS_OK}
            
            
            best = fmin(fn=objetivo,
                        space=space,
                        algo=tpe.suggest,
                        max_evals=500,
                        trials=Trials())
            

            logger.info(f'Best p,d,q parameters: {best}')

            
            # prediccion para calculo error medio
            modelo=ARIMA(train, order=(best['p'], best['d'], best['q']))
            
            modelo.initialize_approximate_diffuse()

            trained = modelo.fit()
            
            error_test_pred=trained.predict(train.shape[0], df.shape[0]-1).fillna(test.mean())
            
            mae_error = mae(test, error_test_pred)  
            rmse_error = mse(test, error_test_pred, squared=False)
            
            stats_train_tmp_df[c+'_pred'] = error_test_pred
            stats_train_tmp_df[c+'_truth'] = test
            stats_train_tmp_df[c+'_error'] = abs(error_test_pred-test)/test*100
            stats_train_tmp_df['zone'] = zone
            stats_train_tmp_df['date'] = df.iloc[test.index].date
            
            
            logger.info(
                        f''':::

                            + MAE: {round(mae_error, 2)} 
                            + RMSE: {round(rmse_error, 2)}  
                            + AVG_ABS_%ERROR: {round(stats_train_tmp_df[c+'_error'].mean(), 2)} 
                            + MEDIAN_ABS_%ERROR: {round(stats_train_tmp_df[c+'_error'].median(), 2)} 
                            + %ERROR_MAE: {round(mae_error/media*100, 2)} 
                            + %ERROR_RMSE: {round(rmse_error/media*100, 2)}
                            '''
                            )
            
            logger.info('next...')
            
            
            
            # prediccion buena para app
            modelo=ARIMA(df[c], order=(best['p'], best['d'], best['q']))
            
            modelo.initialize_approximate_diffuse()

            trained = modelo.fit()

            pred=trained.predict(df.shape[0], df.shape[0]+7).fillna(test.mean())
                        
            tmp_df[c] = abs(pred)
            tmp_df['zone'] = zone
            tmp_df['date'] = [pd.DatetimeIndex(df.iloc[-1:].date) + pd.DateOffset(i) for i in range(1, 9)]
            tmp_df.date = tmp_df.date.apply(lambda x: x[0])
        
        logger.info(stats_train_tmp_df.describe().T)

        stats_train = pd.concat([stats_train, stats_train_tmp_df])
        result = pd.concat([result, tmp_df])
     
    
    stats_train.to_csv(PATH + '/../data/raw/stats_train.csv')
    result.to_csv(PATH + '/../data/raw/time_series_prediction.csv')

    logger.info(stats_train.describe().T)
    logger.info('Done.')

# %%
# Crear la figura principal
fig, ax = plt.subplots()

# Graficar el gráfico principal
ax.plot(dias.values)

# Definir las coordenadas del zoom
x_start, x_end = 50, 80
y_start, y_end = 1000, 1100

# Crear el gráfico secundario para el zoom
axin = ax.inset_axes([0.6, 0.6, 0.3, 0.3])  # (posición x, posición y, ancho, alto)
axin.plot(dias.values)
axin.set_xlim(x_start, x_end)
axin.set_ylim(y_start, y_end)

# Indicar el zoom en el gráfico principal
ax.indicate_inset_zoom(axin)

plt.show()
